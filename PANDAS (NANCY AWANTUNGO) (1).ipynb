# %%
import pandas as pd
import os
from matplotlib import pyplot as plt 
from matplotlib.pyplot import figure
import numpy as np

# %%
data=pd.read_csv(r"C:\Users\desty\Desktop\newss.csv")
print(data)
# Out:
#     Unnamed: 0 employee id   first_name  last_name  \
# 0            0  50-1762417       Dorian    McKeran
# 1            1  31-2853008     Charmion    Pembery
# 2            2  86-9117660       Aurora     Herion
# 3            3  67-9666235         Alfy        Ogg
# 4            4  81-0859807      Kristal     Craney
# ..         ...         ...          ...        ...
# 60          60  91-9906923      Russell   McEnhill
# 61          61  46-8265534       Nollie      Maeer
# 62          62  60-3123845  Christopher  Capinetti
# 63          63  07-2515405      Ezekiel     Lennon
# 64          64  97-5264965         Clim     Arnout
#
#                           email      gender                department  \
# 0           dmckeran0@skype.com        Male        Product Management
# 1   cpembery1@ezinearticles.com  Non-binary      Business Development
# 2       aherion2@soundcloud.com      Female  Research and Development
# ...

# %%
Ama=pd.read_csv(r'C:\Users\desty\Desktop\nana.csv')

# %%
plt.bar(Ama.loc[:,'department'],Ama.loc[:,'ex gratia'])
plt.ylabel('department')
plt.xlabel('ex gratia')
plt.title('department against ex gratia')
plt.show()

# %%
plt.savefig('Ama.png')
plt.show()

# %%
Abena = pd.read_csv(r'C:\Users\desty\Desktop\AB.csv')

# %%
plt.plot(Abena.loc[:,'gender'],Abena.loc[:,'ex gratia'])
plt.ylabel('gender')
plt.xlabel('ex gratia')
plt.title('gender against ex gratia')
plt.show()
plt.savefig('Abena.png')

# %%
Adwoa = pd.read_csv(r'C:\Users\desty\Desktop\ABA.csv')

# %%
plt.bar(Adwoa.loc[:,'job role'],Adwoa.loc[:,'ex gratia'])
plt.ylabel('job role')
plt.xlabel('ex gratia')
plt.title('job role against ex gratia')
plt.show()
plt.savefig('Adwoa.png')

# %%
Kwame = pd.read_csv(r'C:\Users\desty\Desktop\nana.csv')

# %%
plt.bar(Kwame.loc[:,'job role'],Kwame.loc[:,'ex gratia'])
plt.ylabel('job role')
plt.xlabel('ex gratia')
plt.title('job role against ex gratia')
plt.show()
plt.savefig('Kwame.png')
